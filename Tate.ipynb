# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib import rcParams 


data = pd.read_csv('/Users/krupasarna/Downloads/pandas-fundamentals/demos/collection-master/artwork_data.csv')


#data = pd.read_csv(CSV_PATH, nrows=5)
df = pd.read_csv(CSV_PATH, index_col = 'id', usecols = ['id','artist','year','width', 'height'])

#COLS_TO_USE=['id','artist','title','medium','year','acquisitionYear','height','width','units']

#top10 producing artists 
artwork=df['artist'].value_counts().head(10)
print(artwork)
#artwork.plot()

df['artist'].value_counts().head(10).plot(rot=90, kind='bar')
plt.title('Top 10 artists producing work')
plt.xlabel('Artisit Name')
plt.ylabel('Quantity')
# Out:
# /Users/krupasarna/Library/Python/3.8/lib/python/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (9,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Turner, Joseph Mallord William    39389
# Jones, George                      1046
# Moore, Henry, OM, CH                623
# Daniell, William                    612
# Beuys, Joseph                       578
# British (?) School                  388
# Paolozzi, Sir Eduardo               385
# Flaxman, John                       287
# Phillips, Esq Tom                   274
# Warhol, Andy                        272
# Name: artist, dtype: int64
# Text(0, 0.5, 'Quantity')

# %%
import pandas as pd
import os 

df = pd.read_csv('/Users/krupasarna/Downloads/pandas-fundamentals/demos/collection-master/artwork_data.csv', nrows=100, index_col = 'id')
df
# Out:
#       accession_number                             artist artistRole  \
# id
# 1035            A00001                      Blake, Robert     artist
# 1036            A00002                      Blake, Robert     artist
# 1037            A00003                      Blake, Robert     artist
# 1038            A00004                      Blake, Robert     artist
# 1039            A00005                     Blake, William     artist
# ...                ...                                ...        ...
# 1733            A00096  Burne-Jones, Sir Edward Coley, Bt     artist
# 1734            A00097  Burne-Jones, Sir Edward Coley, Bt     artist
# 1735            A00098  Burne-Jones, Sir Edward Coley, Bt     artist
# 1736            A00099  Burne-Jones, Sir Edward Coley, Bt     artist
# 20230           A00100  Burne-Jones, Sir Edward Coley, Bt     artist
#
#        artistId                                              title  \
# id
# ...

# %%
df2= df['width', 'height', 'units']
df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Library/Python/3.8/lib/python/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('width', 'height', 'units')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-231-3f6a1f7cbf57> in <module>
# ...

# %%
#summary of amount of artwork produced in a given year
art_yr=df['acquisitionYear'].value_counts()
print(art_yr)

df['acquisitionYear'].value_counts().head(10).plot(rot=90, kind='bar',)
plt.title("Amount of artwork produced in a given year")
plt.xlabel('Year')
plt.ylabel('Quantity')
# Out:
# 1927    29
# 1919    28
# 1922    22
# 1916    11
# 1896     6
# 1924     2
# 1925     2
# Name: acquisitionYear, dtype: int64
# Text(0, 0.5, 'Quantity')

# %%
df['medium'].value_counts().head(10).plot(rot=360, kind='barh',x= 'quantity', y ='medium type')
df
plt.title('Top 10 Mediums used by Artists')
plt.xlabel('Quantity')
plt.ylabel('Medium')
# Out:
# Text(0, 0.5, 'Medium')

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Library/Python/3.8/lib/python/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'width'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-217-dd7c5b90b158> in <module>
#       1 pd.to_numeric(df['width'], errors='coerce')
# ----> 2 df.loc[:'width']=pd.to_numeric(df['width'], errors='coerce')
#       3
# ...

# %%
speed = [0.1, 17.5, 40, 48, 52, 69, 88]
lifespan = [2, 8, 70, 1.5, 25, 12, 28]
index = ['snail', 'pig', 'elephant',
         'rabbit', 'giraffe', 'coyote', 'horse']
df = pd.DataFrame({'speed': speed,
                   'lifespan': lifespan}, index=index)
ax = df.plot.barh()
